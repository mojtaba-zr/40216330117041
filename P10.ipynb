# %%
def digits(i):
   sum = 0
   while i!= 0:
     sum += i % 10
     i //= 10
   return sum

def func1(n):
  for i in range(1, n+1):
    k = digits(i)
    if k == n:
      return k
  return "not found"

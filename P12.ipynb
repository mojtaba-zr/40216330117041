# %%
class Person:
    name = None
    score = 100
    def say_hello(self):
        print("Hello " + str(self.name) + ", your score is " + str(self.score) + ".")

m = Person()
m.name = "Amir"
m.score = 56
m.say_hello()
# Out:
# Hello Amir, your score is 56.

# %%
def find_min_max_counts(l):
    l.sort()
    count_min = l.count(l[0])
    count_max = l.count(l[-1])
    return l[-1], count_max, l[0], count_min

l = [8, 9, 55, 7, 32, 7]
result = find_min_max_counts(l)
print(result)
# Out:
# (55, 1, 7, 2)

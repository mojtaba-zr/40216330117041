# %%
def maximum100():
    a = input("Enter a number: ")
    a = int(a)
    max = a
    for i in range (0, 100):
        b = int(input("Enter another number: "))
        if b > max:
            max = b
    return max

maximum100()

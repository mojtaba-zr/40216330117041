# %%
#getattr and setattr
class A():
    name = "Ali"
    age = 25

A.name = "Reza"
print(A.name)
test = A()
test.name = "Ahmad"
print(test.age)
print(getattr(A,"name"))
setattr(A,"name","hasan")
print(A.name)
# Out:
# Reza
# 25
# Reza
# hasan

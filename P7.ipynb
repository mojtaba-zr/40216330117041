# %%
def AV():
    counter = 0
    sum = 0
    i = 0
    while i != 1000:
        i = int(input())
        sum += i
        counter += 1
    return (sum - 1000) / (counter - 1)

AV()
# Out:
# 5
# 45
# 45
# 44
# 46
# 1000
# 37.0
